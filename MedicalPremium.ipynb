# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/Medicalpremium.csv')
df
# Out:
#      Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0     45         0                      0               0                   0
# 1     60         1                      0               0                   0
# 2     36         1                      1               0                   0
# 3     52         1                      1               0                   1
# 4     38         0                      0               0                   1
# ..   ...       ...                    ...             ...                 ...
# 981   18         0                      0               0                   0
# 982   64         1                      1               0                   0
# 983   56         0                      1               0                   0
# 984   47         1                      1               0                   0
# 985   21         0                      0               0                   0
#
# ...

# %%
df.head()
# Out:
#    Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0   45         0                      0               0                   0
# 1   60         1                      0               0                   0
# 2   36         1                      1               0                   0
# 3   52         1                      1               0                   1
# 4   38         0                      0               0                   1
#
#    Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 0     155      57               0                        0
# 1     180      73               0                        0
# 2     158      59               0                        0
# 3     183      93               0                        0
# 4     166      88               0                        0
#
#    NumberOfMajorSurgeries  PremiumPrice
# 0                       0         25000
# 1                       0         29000
# ...

# %%
df.tail()
# Out:
#      Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 981   18         0                      0               0                   0
# 982   64         1                      1               0                   0
# 983   56         0                      1               0                   0
# 984   47         1                      1               0                   0
# 985   21         0                      0               0                   0
#
#      Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 981     169      67               0                        0
# 982     153      70               0                        0
# 983     155      71               0                        0
# 984     158      73               1                        0
# 985     158      75               1                        0
#
#      NumberOfMajorSurgeries  PremiumPrice
# 981                       0         15000
# 982                       3         28000
# ...

# %%
df.dtypes
# Out:
# Age                        int64
# Diabetes                   int64
# BloodPressureProblems      int64
# AnyTransplants             int64
# AnyChronicDiseases         int64
# Height                     int64
# Weight                     int64
# KnownAllergies             int64
# HistoryOfCancerInFamily    int64
# NumberOfMajorSurgeries     int64
# PremiumPrice               int64
# dtype: object

# %%
df.describe(percentiles=[.1, .25, .5, .75, .9])

#df.describe
# Out:
#               Age    Diabetes  BloodPressureProblems  AnyTransplants  \
# count  986.000000  986.000000             986.000000      986.000000
# mean    41.745436    0.419878               0.468560        0.055781
# std     13.963371    0.493789               0.499264        0.229615
# min     18.000000    0.000000               0.000000        0.000000
# 10%     22.000000    0.000000               0.000000        0.000000
# 25%     30.000000    0.000000               0.000000        0.000000
# 50%     42.000000    0.000000               0.000000        0.000000
# 75%     53.000000    1.000000               1.000000        0.000000
# 90%     62.000000    1.000000               1.000000        0.000000
# max     66.000000    1.000000               1.000000        1.000000
#
#        AnyChronicDiseases      Height      Weight  KnownAllergies  \
# count          986.000000  986.000000  986.000000      986.000000
# mean             0.180527  168.182556   76.950304        0.215010
# ...

# %%
df.describe(include='all')
# Out:
#               Age    Diabetes  BloodPressureProblems  AnyTransplants  \
# count  986.000000  986.000000             986.000000      986.000000
# mean    41.745436    0.419878               0.468560        0.055781
# std     13.963371    0.493789               0.499264        0.229615
# min     18.000000    0.000000               0.000000        0.000000
# 25%     30.000000    0.000000               0.000000        0.000000
# 50%     42.000000    0.000000               0.000000        0.000000
# 75%     53.000000    1.000000               1.000000        0.000000
# max     66.000000    1.000000               1.000000        1.000000
#
#        AnyChronicDiseases      Height      Weight  KnownAllergies  \
# count          986.000000  986.000000  986.000000      986.000000
# mean             0.180527  168.182556   76.950304        0.215010
# std              0.384821   10.098155   14.265096        0.411038
# min              0.000000  145.000000   51.000000        0.000000
# ...

# %%
df['PremiumPrice'].value_counts()
# Out:
# PremiumPrice
# 23000    249
# 15000    202
# 28000    132
# 25000    103
# 29000     72
# 30000     47
# 35000     41
# 38000     34
# 31000     31
# 21000     26
# 19000     15
# 26000      7
# 39000      5
# 32000      4
# 24000      4
# 16000      3
# 36000      2
# 18000      2
# 34000      2
# 22000      1
# 20000      1
# 40000      1
# 27000      1
# 17000      1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,20))
sns.countplot(y='PremiumPrice',data=df)
plt.tight_layout()

# %%
df.isna().sum()
# Out:
# Age                        0
# Diabetes                   0
# BloodPressureProblems      0
# AnyTransplants             0
# AnyChronicDiseases         0
# Height                     0
# Weight                     0
# KnownAllergies             0
# HistoryOfCancerInFamily    0
# NumberOfMajorSurgeries     0
# PremiumPrice               0
# dtype: int64

# %%
df.corr()
# Out:
#                               Age  Diabetes  BloodPressureProblems  \
# Age                      1.000000  0.210908               0.244888
# Diabetes                 0.210908  1.000000               0.127727
# BloodPressureProblems    0.244888  0.127727               1.000000
# AnyTransplants          -0.008549 -0.036652              -0.024538
# AnyChronicDiseases       0.051072 -0.089428               0.045424
# Height                   0.039879 -0.003783              -0.037926
# Weight                  -0.018590 -0.024563              -0.061016
# KnownAllergies          -0.024416 -0.080102              -0.011550
# HistoryOfCancerInFamily -0.027623 -0.055527               0.048239
# NumberOfMajorSurgeries   0.429181  0.122722               0.251568
# PremiumPrice             0.697540  0.076209               0.167097
#
#                          AnyTransplants  AnyChronicDiseases    Height  \
# Age                           -0.008549            0.051072  0.039879
# ...

# %%
plt.figure(figsize=(19,20))
sns.set(font_scale=2)
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Age', 'Diabetes', 'BloodPressureProblems', 'AnyTransplants',
#        'AnyChronicDiseases', 'Height', 'Weight', 'KnownAllergies',
#        'HistoryOfCancerInFamily', 'NumberOfMajorSurgeries', 'PremiumPrice'],
#       dtype='object')

# %%
df.shape
# Out:
# (986, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      986 non-null    int64
#  1   Diabetes                 986 non-null    int64
#  2   BloodPressureProblems    986 non-null    int64
#  3   AnyTransplants           986 non-null    int64
#  4   AnyChronicDiseases       986 non-null    int64
#  5   Height                   986 non-null    int64
#  6   Weight                   986 non-null    int64
#  7   KnownAllergies           986 non-null    int64
#  8   HistoryOfCancerInFamily  986 non-null    int64
#  9   NumberOfMajorSurgeries   986 non-null    int64
#  10  PremiumPrice             986 non-null    int64
# dtypes: int64(11)
# memory usage: 84.9 KB

# %%
plt.figure(figsize=(20,20))
plt.grid(axis='y',color='green')
x=df['Age']
plt.hist(x)
plt.xlabel('Age')
plt.ylabel('count')
plt.title('Age Distribution')
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %%
sns.pairplot(data=df,hue='PremiumPrice')

# %%
x=df.iloc[:,:-1].values
x
# Out:
# array([[45,  0,  0, ...,  0,  0,  0],
#        [60,  1,  0, ...,  0,  0,  0],
#        [36,  1,  1, ...,  0,  0,  1],
#        ...,
#        [56,  0,  1, ...,  0,  0,  1],
#        [47,  1,  1, ...,  1,  0,  1],
#        [21,  0,  0, ...,  1,  0,  1]])

# %%
y=df.iloc[:,-1].values
y
# Out:
# array([25000, 29000, 23000, 28000, 23000, 23000, 21000, 15000, 23000,
#        23000, 28000, 25000, 15000, 35000, 15000, 23000, 30000, 23000,
#        25000, 15000, 28000, 15000, 32000, 23000, 35000, 21000, 15000,
#        28000, 23000, 21000, 15000, 19000, 15000, 15000, 28000, 28000,
#        23000, 25000, 30000, 15000, 15000, 28000, 15000, 29000, 15000,
#        23000, 32000, 35000, 25000, 15000, 23000, 28000, 28000, 32000,
#        25000, 23000, 29000, 28000, 24000, 23000, 23000, 25000, 15000,
#        23000, 28000, 15000, 28000, 15000, 23000, 21000, 15000, 30000,
#        25000, 38000, 28000, 28000, 15000, 23000, 28000, 38000, 23000,
#        25000, 15000, 23000, 25000, 25000, 38000, 15000, 31000, 21000,
#        25000, 28000, 31000, 28000, 28000, 15000, 23000, 23000, 25000,
#        23000, 15000, 38000, 31000, 15000, 15000, 23000, 25000, 23000,
#        19000, 28000, 29000, 23000, 15000, 23000, 23000, 19000, 28000,
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=30,random_state=42)
x_train
# Out:
# array([[35,  1,  1, ...,  1,  1,  1],
#        [46,  1,  1, ...,  0,  0,  0],
#        [29,  0,  0, ...,  0,  1,  1],
#        ...,
#        [61,  1,  0, ...,  0,  0,  3],
#        [37,  1,  0, ...,  1,  1,  1],
#        [59,  1,  1, ...,  0,  1,  1]])

# %%
x_test
# Out:
# array([[ 50,   0,   0,   0,   0, 165,  84,   1,   1,   1],
#        [ 39,   0,   0,   0,   1, 185,  73,   1,   1,   1],
#        [ 65,   1,   1,   0,   0, 165,  87,   0,   0,   0],
#        [ 29,   0,   0,   0,   0, 179,  70,   0,   1,   1],
#        [ 48,   1,   1,   0,   0, 171,  84,   1,   0,   0],
#        [ 50,   0,   0,   0,   0, 185,  78,   0,   0,   1],
#        [ 47,   0,   1,   0,   0, 175,  57,   0,   0,   0],
#        [ 35,   0,   1,   0,   0, 168,  87,   1,   0,   0],
#        [ 55,   1,   1,   0,   0, 169,  73,   0,   0,   2],
#        [ 64,   1,   1,   0,   0, 178,  62,   0,   1,   2],
#        [ 33,   0,   1,   0,   1, 177,  65,   0,   0,   0],
#        [ 44,   0,   1,   0,   1, 180,  88,   0,   0,   0],
#        [ 21,   0,   1,   0,   0, 179,  80,   1,   0,   0],
#        [ 28,   1,   1,   0,   0, 147,  69,   0,   0,   1],
#        [ 40,   0,   0,   1,   0, 164,  87,   0,   0,   0],
#        [ 49,   1,   1,   0,   0, 154,  97,   0,   0,   2],
# ...

# %%
y_train
# Out:
# array([31000, 23000, 15000, 25000, 15000, 35000, 23000, 23000, 15000,
#        28000, 25000, 23000, 23000, 23000, 21000, 25000, 29000, 25000,
#        26000, 23000, 23000, 21000, 25000, 15000, 30000, 23000, 23000,
#        25000, 25000, 29000, 23000, 15000, 25000, 23000, 31000, 28000,
#        38000, 15000, 28000, 29000, 35000, 23000, 23000, 15000, 15000,
#        15000, 28000, 23000, 21000, 15000, 15000, 36000, 25000, 15000,
#        23000, 25000, 23000, 29000, 35000, 15000, 28000, 38000, 28000,
#        29000, 23000, 34000, 23000, 15000, 30000, 29000, 25000, 15000,
#        28000, 15000, 38000, 28000, 23000, 15000, 25000, 15000, 28000,
#        23000, 15000, 29000, 31000, 23000, 25000, 23000, 15000, 25000,
#        38000, 31000, 35000, 35000, 29000, 28000, 29000, 38000, 15000,
#        35000, 23000, 15000, 28000, 23000, 38000, 18000, 30000, 23000,
#        29000, 23000, 23000, 23000, 30000, 31000, 23000, 29000, 35000,
# ...

# %%
y_test
# Out:
# array([31000, 31000, 29000, 15000, 23000, 29000, 25000, 23000, 28000,
#        28000, 21000, 30000, 15000, 15000, 38000, 28000, 28000, 35000,
#        28000, 23000, 38000, 15000, 23000, 22000, 38000, 25000, 25000,
#        30000, 15000, 28000])

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x_train)
x_train=scaler.transform(x_train)
x_test=scaler.transform(x_test)
x_train
# Out:
# array([[-0.4770003 ,  1.16390713,  1.07159442, ...,  1.91400487,
#          2.77324883,  0.4487571 ],
#        [ 0.30935104,  1.16390713,  1.07159442, ..., -0.52246471,
#         -0.36058791, -0.88772821],
#        [-0.90591922, -0.85917508, -0.93318888, ..., -0.52246471,
#          2.77324883,  0.4487571 ],
#        ...,
#        [ 1.38164832,  1.16390713, -0.93318888, ..., -0.52246471,
#         -0.36058791,  3.12172771],
#        [-0.33402733,  1.16390713, -0.93318888, ...,  1.91400487,
#          2.77324883,  0.4487571 ],
#        [ 1.23867535,  1.16390713,  1.07159442, ..., -0.52246471,
#          2.77324883,  0.4487571 ]])

# %%
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier(n_neighbors=6)
model.fit(x_train,y_train)
y_neighbors=model.predict(x_test)
y_neighbors
# Out:
# array([31000, 30000, 29000, 15000, 23000, 23000, 25000, 15000, 28000,
#        28000, 30000, 30000, 15000, 23000, 15000, 28000, 28000, 25000,
#        28000, 15000, 38000, 25000, 23000, 15000, 38000, 25000, 23000,
#        30000, 15000, 28000])

# %%
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix
mat=confusion_matrix(y_test,y_neighbors)
mat
Neighbors_score=accuracy_score(y_test,y_neighbors)
Neighbors_score
report=classification_report(y_test,y_neighbors)
report
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
from sklearn.svm import SVC
model=SVC()
model.fit(x_train,y_train)
y_svm=model.predict(x_test)
y_svm
# Out:
# array([31000, 30000, 29000, 15000, 23000, 29000, 25000, 23000, 28000,
#        28000, 23000, 30000, 15000, 15000, 38000, 28000, 28000, 29000,
#        28000, 15000, 38000, 15000, 23000, 31000, 38000, 25000, 23000,
#        30000, 15000, 28000])

# %%
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix
mat=confusion_matrix(y_test,y_svm)
mat
SVC_score=accuracy_score(y_test,y_svm)
SVC_score
report=classification_report(y_test,y_svm)
report
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(x_train,y_train)
y_tree=model.predict(x_test)
y_tree
# Out:
# array([31000, 26000, 29000, 15000, 23000, 29000, 25000, 23000, 28000,
#        28000, 23000, 30000, 32000, 15000, 38000, 28000, 28000, 35000,
#        28000, 26000, 38000, 15000, 23000, 31000, 38000, 25000, 25000,
#        30000, 16000, 28000])

# %%
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix
mat=confusion_matrix(y_test,y_tree)
mat
Tree_score=accuracy_score(y_test,y_tree)
Tree_score
report=classification_report(y_test,y_tree)
report
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier()
model.fit(x_train,y_train)
y_ran=model.predict(x_test)
y_ran
# Out:
# array([31000, 30000, 29000, 15000, 23000, 29000, 25000, 23000, 28000,
#        28000, 21000, 30000, 15000, 15000, 38000, 28000, 28000, 29000,
#        28000, 26000, 38000, 15000, 23000, 31000, 38000, 25000, 25000,
#        30000, 15000, 28000])

# %%
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix
mat=confusion_matrix(y_test,y_ran)
mat
Random_score=accuracy_score(y_test,y_ran)
Random_score
report=classification_report(y_test,y_ran)
report
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd

model = LinearRegression()
model.fit(x_train, y_train)


y_pred = model.predict(x_test)


LinearReg_score = r2_score(y_test, y_pred)  # R² score as performance metric


from sklearn.metrics import classification_report,accuracy_score,confusion_matrix
mat=confusion_matrix(y_test,y_tree)
mat
Tree_score=accuracy_score(y_test,y_tree)
Tree_score
report=classification_report(y_test,y_tree)
report
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
alg = ['KNN', 'SVM', 'DecisionTree', 'RandomForest', 'LinearRegression']
acc = [Neighbors_score, SVC_score, Tree_score, Random_score, LinearReg_score]
accuracy_score = pd.DataFrame({'Algorithms': alg, 'Accuracy': acc})
accuracy_score['Accuracy'] = accuracy_score['Accuracy'] * 100

# Display the accuracy scores
accuracy_score
# Out:
#          Algorithms   Accuracy
# 0               KNN  63.333333
# 1               SVM  80.000000
# 2      DecisionTree  80.000000
# 3      RandomForest  86.666667
# 4  LinearRegression  76.153161

# %%
accuracy_score.sort_values(by='Accuracy',ascending=False)
# Out:
#          Algorithms   Accuracy
# 3      RandomForest  86.666667
# 2      DecisionTree  80.000000
# 1               SVM  80.000000
# 4  LinearRegression  76.153161
# 0               KNN  63.333333

# %%
ax=sns.barplot(y='Algorithms',x='Accuracy',palette='muted',data=accuracy_score.sort_values(by='Accuracy',ascending=False)
)
for i in ax.containers:
  ax.bar_label(i,)
  plt.tight_layout()
# Out:
# <ipython-input-155-24957ab92c08>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.barplot(y='Algorithms',x='Accuracy',palette='muted',data=accuracy_score.sort_values(by='Accuracy',ascending=False)
